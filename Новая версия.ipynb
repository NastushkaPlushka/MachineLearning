# %%
# Игнорирем предупреждения
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Импортируем библиотеки необходимые для работы

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### Загрузка данных

# %%
house_boston = load_boston()

# %%
df = pd.DataFrame(data = house_boston.data, columns = house_boston.feature_names)

# %%
df["MEDV"] = house_boston.target

# %% [markdown]
# ### Предварительный анализ

# %% [markdown]
# #### Вывод информации о количественных характеристиках датасета

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# #### Вывод информации об отсутствующих значениях и характеристиках

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %% [markdown]
# #### Вывод нескольких точек данных для иллюстрации структуры данных.

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Описательный анализ данных

# %%
df[df.columns[:7]].describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE
# count  506.000000
# mean    68.574901
# std     28.148861
# min      2.900000
# 25%     45.025000
# 50%     77.500000
# 75%     94.075000
# max    100.000000

# %%
df[df.columns[7:]].describe()
# Out:
#               DIS         RAD         TAX     PTRATIO           B       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# std      2.105710    8.707259  168.537116    2.164946   91.294864    7.141062
# min      1.129600    1.000000  187.000000   12.600000    0.320000    1.730000
# 25%      2.100175    4.000000  279.000000   17.400000  375.377500    6.950000
# 50%      3.207450    5.000000  330.000000   19.050000  391.440000   11.360000
# 75%      5.188425   24.000000  666.000000   20.200000  396.225000   16.955000
# max     12.126500   24.000000  711.000000   22.000000  396.900000   37.970000
#
#              MEDV
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %%
for col in df.columns:
    df[col].hist(figsize=(3, 3))
    plt.title(col)
    plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 9))
sns.heatmap(
    df.corr().round(5),
    annot=True,
    annot_kws={'size': 10},
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(10, 240, n=200))
plt.show()

# %%
df.drop('RAD', axis = 1)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  296.0     15.3
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  242.0     17.8
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  242.0     17.8
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  222.0     18.7
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  222.0     18.7
# ..       ...   ...    ...   ...    ...    ...   ...     ...    ...      ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  273.0     21.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  273.0     21.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  273.0     21.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  273.0     21.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  273.0     21.0
#
#           B  LSTAT  MEDV
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    392.83   4.03  34.7
# 3    394.63   2.94  33.4
# 4    396.90   5.33  36.2
# ..      ...    ...   ...
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9
#
# [506 rows x 13 columns]

# %% [markdown]
# ### Разделение набора данных на обучающую и тестовую выборки

# %%
X = df[["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "TAX", "PTRATIO", "B", "LSTAT"]]
Y = df["MEDV"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30, random_state = 101)

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# #### «Случайный лес»

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest = RandomForestRegressor()
random_forest.fit(X_train, Y_train)

cv_score_random_forest = cross_val_score(random_forest,X_train, Y_train, cv=4).mean()

score_random_forest = random_forest.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_random_forest)
print('Score на test = %0.4f' % score_random_forest)
# Out:
# Score на train = 0.8260
# Score на test = 0.8533

# %% [markdown]
# #### Градиентный бустинг

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gradient_boosted = GradientBoostingRegressor()
gradient_boosted.fit(X_train, Y_train)

cv_score_gradient_boosted = cross_val_score(gradient_boosted,X_train, Y_train, cv=4).mean()

score_gradient_boosted = gradient_boosted.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_gradient_boosted)
print('Score на test = %0.4f' % score_gradient_boosted)
# Out:
# Score на train = 0.8485
# Score на test = 0.8805

# %% [markdown]
# #### Деревья решений

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
decision_tree = DecisionTreeRegressor()
decision_tree.fit(X_train, Y_train)

cv_score_decision_tree = cross_val_score(decision_tree, X_train, Y_train, cv=4).mean()

score_decision_tree = decision_tree.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_decision_tree)
print('Score на test = %0.4f' % score_decision_tree)
# Out:
# Score на train = 0.7409
# Score на test = 0.7769

# %% [markdown]
# #### Оценка качества моделей со стандартным набором гиперпараметров

# %%
cross_validation_score = [cv_score_random_forest, cv_score_gradient_boosted, cv_score_decision_tree]
score = [score_random_forest ,score_gradient_boosted ,score_decision_tree]
name = ['Случайный лес', 'Градиентный бустинг', 'Деревья решений']

# %%
width = 0.3
x = np.arange(len(name))
fig, ax = plt.subplots(figsize=(10,6))
cross_validation_bar = ax.bar(x - width/2, cross_validation_score, width, label='cross_validation_score', color= '#e25e74')
score_bar = ax.bar(x + width/2, score, width, label='score', color='#399cbd')
ax.set_title('Оценка качества моделей со стандартным набором гиперпараметров')
ax.set_xticks(x)
ax.set_xticklabels(name)
ax.legend()
plt.show()

# %% [markdown]
# # Оптимизация гиперпараметров модели DecisionTree

# %%
param_optimization = {'criterion': ['squared_error', "friedman_mse", 'absolute_error', "poisson"],
               'max_depth': list(np.linspace(2, 100, 20, dtype = int)) + [None],
               'min_samples_leaf': list(np.linspace(1, 100, 10, dtype = int)),
               'min_samples_split': list(np.linspace(1, 100, 10, dtype = int))}

# %% [markdown]
# ## Random Search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# %%time
decision_tree = DecisionTreeRegressor()
decision_tree_model_random_search = RandomizedSearchCV(estimator = decision_tree, param_distributions = param_optimization, n_iter = 100, cv = 4, verbose= 1, random_state= 31, n_jobs = -1)

decision_tree_model_random_search.fit(X_train,Y_train)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Wall time: 2.94 s
# RandomizedSearchCV(cv=4, estimator=DecisionTreeRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['squared_error',
#                                                       'friedman_mse',
#                                                       'absolute_error',
#                                                       'poisson'],
#                                         'max_depth': [2, 7, 12, 17, 22, 27, 32,
#                                                       38, 43, 48, 53, 58, 63,
#                                                       69, 74, 79, 84, 89, 94,
#                                                       100, None],
#                                         'min_samples_leaf': [1, 12, 23, 34, 45,
#                                                              56, 67, 78, 89,
#                                                              100],
#                                         'min_samples_split': [1, 12, 23, 34, 45,
#                                                               56, 67, 78, 89,
#                                                               100]},
#                    random_state=31, verbose=1)

# %%
decision_tree_model_random_search.best_params_
# Out:
# {'min_samples_split': 34,
#  'min_samples_leaf': 12,
#  'max_depth': 38,
#  'criterion': 'absolute_error'}

# %%
cv_score_decision_tree_random_search = cross_val_score(decision_tree_model_random_search,X_train, Y_train, cv=4).mean()

score_decision_tree_random_search = decision_tree_model_random_search.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_decision_tree_random_search)
print('Score на test = %0.4f' % score_decision_tree_random_search)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Score на train = 0.7063
# Score на test = 0.7844

# %% [markdown]
# ## Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
# %%time
decision_tree = DecisionTreeRegressor()
decision_tree_model_grid_search = GridSearchCV(estimator = decision_tree, param_grid = param_optimization, cv = 4, verbose= 1, n_jobs = -1)

decision_tree_model_grid_search.fit(X_train,Y_train)
# Out:
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Wall time: 52.5 s
# GridSearchCV(cv=4, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [2, 7, 12, 17, 22, 27, 32, 38, 43, 48, 53,
#                                        58, 63, 69, 74, 79, 84, 89, 94, 100,
#                                        None],
#                          'min_samples_leaf': [1, 12, 23, 34, 45, 56, 67, 78, 89,
#                                               100],
#                          'min_samples_split': [1, 12, 23, 34, 45, 56, 67, 78,
#                                                89, 100]},
#              verbose=1)

# %%
decision_tree_model_grid_search.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 7,
#  'min_samples_leaf': 1,
#  'min_samples_split': 23}

# %%
cv_score_decision_tree_grid_search = cross_val_score(decision_tree_model_grid_search,X_train, Y_train, cv=4).mean()

score_decision_tree_grid_search = decision_tree_model_grid_search.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_decision_tree_grid_search)
print('Score на test = %0.4f' % score_decision_tree_grid_search)
# Out:
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Score на train = 0.7871
# Score на test = 0.8394

# %% [markdown]
# ## Байесовская оптимизация

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

# %%
space = {'criterion': hp.choice('criterion', ['squared_error', 'friedman_mse', 'absolute_error', 'poisson']),
         'max_depth': hp.uniform('max_depth', 2, 100),
         'min_samples_leaf': hp.uniform('min_samples_leaf', 1, 100),
         'min_samples_split' : hp.uniform('min_samples_split', 1, 100)}

# %%
def objective(space):
    
    model = DecisionTreeRegressor(criterion = space['criterion'],
                                  max_depth = int(space['max_depth']),
                                  min_samples_leaf = int(space['min_samples_leaf']),
                                  min_samples_split = int(space['min_samples_split']))
    
    accuracy = cross_val_score(model, X_train, Y_train, cv=4).mean()

    return {'loss': -accuracy, 'status': STATUS_OK }

# %%
# %%time
trials = Trials()

best = fmin(fn = objective,
            space = space,
            algo = tpe.suggest,
            max_evals = 80,
            trials = trials)

crit = {0: 'squared_error', 1: 'friedman_mse', 2: 'absolute_error', 3: 'poisson'}

decision_tree_model_baev_optimization = DecisionTreeRegressor(criterion = crit[best['criterion']],
                                                              max_depth = int(best['max_depth']), 
                                                              min_samples_leaf = int(best['min_samples_leaf']), 
                                                              min_samples_split = int(best['min_samples_split']))
decision_tree_model_baev_optimization.fit(X_train,Y_train)
# Out:
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 33.79trial/s, best loss: -0.7657134234843433]
# Wall time: 2.38 s
# DecisionTreeRegressor(criterion='absolute_error', max_depth=89,
#                       min_samples_leaf=12, min_samples_split=6)

# %%
best
# Out:
# {'criterion': 2,
#  'max_depth': 89.1283429945205,
#  'min_samples_leaf': 12.130677133702193,
#  'min_samples_split': 6.978015177014953}

# %%
cv_score_decision_tree_baev_optimization = cross_val_score(decision_tree_model_baev_optimization,X_train, Y_train, cv=4).mean()

score_decision_tree_baev_optimization = decision_tree_model_baev_optimization.score(X_test, Y_test)

print('Score на train = %0.4f' % cv_score_decision_tree_baev_optimization)
print('Score на test = %0.4f' % score_decision_tree_baev_optimization)
# Out:
# Score на train = 0.7655
# Score на test = 0.7870

# %% [markdown]
# #### Оценка прироста качества модели от метода оптимизации

# %%
development_random_search = 100 * ((score_decision_tree_random_search - score_decision_tree) / score_decision_tree)
development_grid_search = 100 * ((score_decision_tree_grid_search - score_decision_tree) / score_decision_tree)
development_baev_optimization = 100 * ((score_decision_tree_baev_optimization - score_decision_tree) / score_decision_tree)

# %%
plt.subplots(figsize=(10, 10))
sns.barplot(['Random Serch', 'Grid Search', 'Байевская оптимизация'], [development_random_search, development_grid_search, development_baev_optimization], palette=sns.diverging_palette(5, 240, n=200))
plt.title('Оценка прироста качества модели от метода оптимизации')
plt.show()

# %% [markdown]
# #### Оценка качества модели  с разными методами оптимизации гиперпараметров

# %%
cross_validation_score = [cv_score_decision_tree, cv_score_decision_tree_random_search, cv_score_decision_tree_grid_search, cv_score_decision_tree_baev_optimization]
score = [score_decision_tree, score_decision_tree_random_search ,score_decision_tree_grid_search ,score_decision_tree_baev_optimization]
name = ['Стандартные гиперпараметры', 'Random Serch', 'Grid Search', 'Байевская оптимизация']

# %%
width = 0.3
x = np.arange(len(name))
fig, ax = plt.subplots(figsize=(10,6))
cross_validation_bar = ax.bar(x - width/2, cross_validation_score, width, label='cross_validation_score', color= '#e25e74')
score_bar = ax.bar(x + width/2, score, width, label='score', color='#399cbd')
ax.set_title('Оценка качества модели с разными методами оптимизации гиперпараметров')
ax.set_xticks(x)
ax.set_xticklabels(name)
ax.legend()
plt.show()

# %% [markdown]
# # Эксперимент, определяющий зависимость получения разных результатов при разных запусках алгоритма от размерности данных

# %% [markdown]
# #### Random Search

# %%
list_score_decision_tree_random_search = []

for i in range(0, 10):
    
    decision_tree = DecisionTreeRegressor()
    decision_tree_model_random_search = RandomizedSearchCV(estimator = decision_tree, param_distributions = param_optimization, n_iter = 100, cv = 4, verbose= 1, random_state= 31, n_jobs = -1)

    decision_tree_model_random_search.fit(X_train,Y_train)
    
    score_decision_tree_random_search = decision_tree_model_random_search.score(X_test, Y_test)
    
    list_score_decision_tree_random_search.append(score_decision_tree_random_search)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits

# %% [markdown]
# #### Grid Search

# %%
list_score_decision_tree_grid_search = []

for i in range(0, 10):
    
    decision_tree = DecisionTreeRegressor()
    decision_tree_model_grid_search = GridSearchCV(estimator = decision_tree, param_grid = param_optimization, cv = 4, verbose= 1, n_jobs = -1)

    decision_tree_model_grid_search.fit(X_train,Y_train)
    
    score_decision_tree_grid_search = decision_tree_model_grid_search.score(X_test, Y_test)
    
    list_score_decision_tree_grid_search.append(score_decision_tree_grid_search)
# Out:
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits

# %% [markdown]
# #### Байесовская оптимизация

# %%
list_score_decision_tree_baev_optimization = []

for i in range(0, 10):
    
    trials = Trials()

    best = fmin(fn = objective,
                space = space,
                algo = tpe.suggest,
                max_evals = 80,
                trials = trials)

    crit = {0: 'squared_error', 1: 'friedman_mse', 2: 'absolute_error', 3: 'poisson'}

    decision_tree_model_baev_optimization = DecisionTreeRegressor(criterion = crit[best['criterion']],
                                                                  max_depth = int(best['max_depth']), 
                                                                  min_samples_leaf = int(best['min_samples_leaf']), 
                                                                  min_samples_split = int(best['min_samples_split']))
    decision_tree_model_baev_optimization.fit(X_train, Y_train)
    
    score_decision_tree_baev_optimization = decision_tree_model_baev_optimization.score(X_test, Y_test)
    
    list_score_decision_tree_baev_optimization.append(score_decision_tree_baev_optimization)
# Out:
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 32.41trial/s, best loss: -0.7478994452032757]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 33.99trial/s, best loss: -0.7557061970392129]
# 100%|████████████████████████████████████████████████| 80/80 [00:02<00:00, 33.54trial/s, best loss: -0.765471355550247]
# 100%|████████████████████████████████████████████████| 80/80 [00:02<00:00, 31.40trial/s, best loss: -0.765471355550247]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 35.94trial/s, best loss: -0.7649132787944168]
# 100%|████████████████████████████████████████████████| 80/80 [00:02<00:00, 34.70trial/s, best loss: -0.756907886480743]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 37.28trial/s, best loss: -0.7457373032842198]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 35.88trial/s, best loss: -0.7627639233917664]
# 100%|████████████████████████████████████████████████| 80/80 [00:01<00:00, 40.97trial/s, best loss: -0.769859534702559]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 36.49trial/s, best loss: -0.7609472248516451]

# %%
list_optimization = list(zip(list_score_decision_tree_random_search, list_score_decision_tree_grid_search, list_score_decision_tree_baev_optimization, list(range(1, 11))))
df_optimization = pd.DataFrame(list_optimization, columns=['Random search', 'Grid search', 'Байесовская оптимизация', 'Номер итерации'])
df_optimization.set_index('Номер итерации',inplace=True)
df_optimization
# Out:
#                 Random search  Grid search  Байесовская оптимизация
# Номер итерации
# 1                    0.820594     0.841560                 0.789620
# 2                    0.820594     0.839438                 0.780566
# 3                    0.814460     0.839438                 0.787042
# 4                    0.820594     0.820594                 0.788715
# 5                    0.820594     0.839438                 0.788715
# 6                    0.820594     0.841560                 0.788363
# 7                    0.784127     0.841560                 0.723753
# 8                    0.820594     0.839438                 0.812993
# 9                    0.784127     0.839438                 0.852208
# 10                   0.784127     0.839438                 0.788448

# %%
x = list(range(1, 11))
for y in [list_score_decision_tree_random_search, list_score_decision_tree_grid_search, list_score_decision_tree_baev_optimization]:
    
    plt.plot(x, y, '#e25e74', linewidth=2.0)
    plt.title('Без понижения размерности')
    max_difference = 'Максимальная разница между качеством модели = ' + str(max(y) - min(y))
    plt.xlabel(max_difference)
    plt.show()

# %% [markdown]
# ## Уменьшаем размерность

# %%
from sklearn.decomposition import PCA
import seaborn as sns; sns.set()

# %%
pca = PCA(n_components=.5)
pca.fit(df)
df_pca = pca.transform(df)

# %%
df_new = pca.inverse_transform(df_pca)

# %%
df_new = pd.DataFrame(data = df_new, columns = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"])

# %%
df_new.drop('RAD', axis = 1)
# Out:
#          CRIM         ZN     INDUS      CHAS       NOX        RM        AGE  \
# 0    0.103563  16.589115  7.742520  0.075864  0.500818  6.424909  58.554152
# 1   -1.331611  18.725741  6.354655  0.078601  0.478788  6.482265  54.456807
# 2   -1.353764  18.758721  6.333232  0.078643  0.478448  6.483150  54.393561
# 3   -1.965400  19.669299  5.741758  0.079810  0.469059  6.507594  52.647373
# 4   -1.964642  19.668171  5.742490  0.079808  0.469071  6.507564  52.649535
# ..        ...        ...       ...       ...       ...       ...        ...
# 501 -0.448058  17.410345  7.209082  0.076916  0.492350  6.446954  56.979304
# 502 -0.470332  17.443506  7.187542  0.076959  0.492009  6.447844  56.915712
# 503 -0.440072  17.398456  7.216805  0.076901  0.492473  6.446635  57.002103
# 504 -0.412817  17.357881  7.243161  0.076849  0.492891  6.445546  57.079912
# 505 -0.454625  17.420122  7.202732  0.076929  0.492250  6.447217  56.960555
#
#           DIS         TAX    PTRATIO           B     LSTAT       MEDV
# 0    4.580960  294.481065  17.784197  391.562094  9.901908  25.591545
# 1    4.902310  247.967789  17.509696  405.827335  8.776999  26.842220
# 2    4.907271  247.249813  17.505459  406.047533  8.759635  26.861526
# 3    5.044222  227.426997  17.388474  412.127028  8.280227  27.394533
# 4    5.044053  227.451537  17.388619  412.119502  8.280820  27.393873
# ..        ...         ...        ...         ...       ...        ...
# 501  4.704473  276.603308  17.678690  397.045056  9.469540  26.072252
# 502  4.709461  275.881414  17.674430  397.266455  9.452081  26.091663
# 503  4.702685  276.862122  17.680218  396.965679  9.475800  26.065293
# 504  4.696583  277.745420  17.685431  396.694779  9.497162  26.041542
# 505  4.705944  276.390469  17.677434  397.110332  9.464393  26.077975
#
# [506 rows x 13 columns]

# %% [markdown]
# ### Разделение набора данных на обучающую и тестовую выборки

# %%
X_new = df[["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "TAX", "PTRATIO", "B", "LSTAT"]]
Y_new = df["MEDV"]

# %%
X_train_new, X_test_new, Y_train_new, Y_test_new = train_test_split(X_new, Y_new, test_size = 0.30, random_state = 101)

# %% [markdown]
# #### Деревья решений

# %%
decision_tree_new = DecisionTreeRegressor()
decision_tree_new.fit(X_train_new, Y_train_new)

cv_score_decision_tree_new = cross_val_score(decision_tree_new, X_train_new, Y_train_new, cv=4).mean()

score_decision_tree_new = decision_tree_new.score(X_test_new, Y_test_new)

print('Score на train = %0.4f' % cv_score_decision_tree_new)
print('Score на test = %0.4f' % score_decision_tree_new)
# Out:
# Score на train = 0.7404
# Score на test = 0.7886

# %% [markdown]
# ## Оптимизация гиперпараметров модели DecisionTree

# %% [markdown]
# ## Random Search

# %%
list_score_decision_tree_random_search_new = []

for i in range(0, 10):
    
    decision_tree_new = DecisionTreeRegressor()
    decision_tree_model_random_search_new = RandomizedSearchCV(estimator = decision_tree_new, param_distributions = param_optimization, n_iter = 100, cv = 4, verbose= 1, random_state= 31, n_jobs = -1)

    decision_tree_model_random_search_new.fit(X_train_new,Y_train_new)
    
    score_decision_tree_random_search_new = decision_tree_model_random_search_new.score(X_test_new, Y_test_new)
    
    list_score_decision_tree_random_search_new.append(score_decision_tree_random_search_new)
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# Fitting 4 folds for each of 100 candidates, totalling 400 fits

# %% [markdown]
# ## Grid Search

# %%
list_score_decision_tree_grid_search_new = []

for i in range(0, 10):
    
    decision_tree_new = DecisionTreeRegressor()
    decision_tree_model_grid_search_new = GridSearchCV(estimator = decision_tree_new, param_grid = param_optimization, cv = 4, verbose= 1, n_jobs = -1)

    decision_tree_model_grid_search_new.fit(X_train_new,Y_train_new)
    
    score_decision_tree_grid_search_new = decision_tree_model_grid_search_new.score(X_test_new, Y_test_new)
    
    list_score_decision_tree_grid_search_new.append(score_decision_tree_grid_search_new)
# Out:
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits
# Fitting 4 folds for each of 8400 candidates, totalling 33600 fits

# %% [markdown]
# ## Байесовская оптимизация

# %%
list_score_decision_tree_baev_optimization_new = []

for i in range(0, 10):
    
    trials = Trials()

    best = fmin(fn = objective,
                space = space,
                algo = tpe.suggest,
                max_evals = 80,
                trials = trials)

    crit = {0: 'squared_error', 1: 'friedman_mse', 2: 'absolute_error', 3: 'poisson'}

    decision_tree_model_baev_optimization_new = DecisionTreeRegressor(criterion = crit[best['criterion']],
                                                                  max_depth = int(best['max_depth']), 
                                                                  min_samples_leaf = int(best['min_samples_leaf']), 
                                                                  min_samples_split = int(best['min_samples_split']))
    decision_tree_model_baev_optimization_new.fit(X_train_new, Y_train_new)
    
    score_decision_tree_baev_optimization_new = decision_tree_model_baev_optimization_new.score(X_test_new, Y_test_new)
    
    list_score_decision_tree_baev_optimization_new.append(score_decision_tree_baev_optimization_new)
# Out:
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 31.19trial/s, best loss: -0.7496534308113447]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 35.28trial/s, best loss: -0.7430816706343176]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 37.84trial/s, best loss: -0.7516764439938817]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 32.65trial/s, best loss: -0.7492226487566751]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 28.76trial/s, best loss: -0.7651553467285132]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 33.37trial/s, best loss: -0.7285986535675593]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 24.41trial/s, best loss: -0.7551438241262329]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 39.32trial/s, best loss: -0.7811848432196304]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 33.29trial/s, best loss: -0.7551438241262329]
# 100%|███████████████████████████████████████████████| 80/80 [00:02<00:00, 23.84trial/s, best loss: -0.7657134234843433]

# %%
list_optimization = list(zip(list_score_decision_tree_random_search_new, list_score_decision_tree_grid_search_new, list_score_decision_tree_baev_optimization_new, list(range(1, 11))))
df_optimization = pd.DataFrame(list_optimization, columns=['Random search', 'Grid search', 'Байесовская оптимизация', 'Номер итерации'])
df_optimization.set_index('Номер итерации',inplace=True)
df_optimization
# Out:
#                 Random search  Grid search  Байесовская оптимизация
# Номер итерации
# 1                    0.784449     0.841560                 0.735339
# 2                    0.784449     0.814460                 0.809178
# 3                    0.784449     0.841560                 0.834948
# 4                    0.784449     0.839438                 0.728880
# 5                    0.784127     0.839438                 0.788715
# 6                    0.814460     0.841560                 0.714052
# 7                    0.820594     0.814460                 0.784499
# 8                    0.814460     0.841560                 0.820104
# 9                    0.831254     0.814460                 0.783523
# 10                   0.820594     0.839438                 0.787042

# %%
x = list(range(1, 11))
for y in [list_score_decision_tree_random_search_new, list_score_decision_tree_grid_search_new, list_score_decision_tree_baev_optimization_new]:
    
    plt.plot(x, y, '#e25e74', linewidth=2.0)
    plt.title('С понижением размерности')
    max_difference = 'Максимальная разница между качеством модели = ' + str(max(y) - min(y))
    plt.xlabel(max_difference)
    plt.show()
